# %% [markdown]
# # Download Train and Test data

# %%
import os
DATA_PATH = '/content/'
os.chdir(DATA_PATH)

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_data.zip
# !unzip nyu_data.zip

# %%
#!wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_test.zip

# %% [markdown]
# # Set Paths

# %%
import os
DATA_PATH = '/content/'
SAVE_PATH = '/content/'
os.chdir(SAVE_PATH)
os.getcwd()
# Out:
# '/content'

# %%
try:
    # %tensorflow_version 2.x
except:
    pass
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Loss function

# %%
def depth_loss(y_true, y_pred, theta=0.1, maxDepthVal=1000.0/10.0):
    # Point-wise depth
    l_depth = K.mean(K.abs(y_pred - y_true), axis=-1)

    # Edges
    dy_true, dx_true = tf.image.image_gradients(y_true)
    dy_pred, dx_pred = tf.image.image_gradients(y_pred)
    l_edges = K.mean(K.abs(dy_pred - dy_true) + K.abs(dx_pred - dx_true), axis=-1)

    # Structural similarity (SSIM) index
    l_ssim = K.clip((1 - tf.image.ssim(y_true, y_pred, maxDepthVal)) * 0.5, 0, 1)

    # Weights
    w1 = 1.0
    w2 = 1.0
    w3 = theta

    return (w1 * l_ssim) + (w2 * K.mean(l_edges)) + (w3 * K.mean(l_depth))

# %% [markdown]
# # Define Model

# %% [markdown]
# ## Upscale block

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, UpSampling2D, LeakyReLU, Concatenate
from tensorflow.keras.applications import DenseNet169

class UpscaleBlock(Model):
    def __init__(self, filters):
        # call parent constructor
        super(UpscaleBlock, self).__init__()
        ALPHA = 0.2

        self.upscl = UpSampling2D(interpolation='bilinear')
        self.cncat = Concatenate()

        self.convA = Conv2D(filters, (3, 3) , padding='same')
        self.reluA = LeakyReLU(alpha=ALPHA)  

        self.convB = Conv2D(filters, (3, 3), padding='same')
        self.reluB = LeakyReLU(alpha=ALPHA)
    
    def call(self, inputs):
        x = self.upscl(inputs[0])
        x = self.cncat([x, inputs[1]])
        
        x = self.convA(x)
        x = self.reluA(x)

        x = self.convB(x)
        x = self.reluB(x)

        return x

# %% [markdown]
# ## Encode Block

# %%
class Encoder(Model):
    def __init__(self):
        super(Encoder, self).__init__()

        self.base = DenseNet169(input_shape=(None, None, 3) ,include_top=False)

        outputs = [self.base.outputs[-1]]
        for name in ['pool1', 'pool2_pool', 'pool3_pool', 'conv1/relu']:
            outputs.append(self.base.get_layer(name).output)

        self.encoder = Model(inputs = self.base.inputs, outputs = outputs)       

    def call(self, inputs):
        x = self.encoder(inputs)
        return x

# %% [markdown]
# ## Decode Block

# %%
class Decoder(Model):
    def __init__(self, filters):
        super(Decoder, self).__init__()

        self.convA = Conv2D(filters, (1, 1), padding='same')

        self.upA = UpscaleBlock(filters=filters//2)
        self.upB = UpscaleBlock(filters=filters//4)
        self.upC = UpscaleBlock(filters=filters//8)
        self.upD = UpscaleBlock(filters=filters//16)

        self.convB = Conv2D(1, (3, 3), padding='same')
    
    def call(self, inputs):
        x, pool1, pool2, pool3, conv1 = inputs[0], inputs[1], inputs[2], inputs[3], inputs[4]

        x = self.convA(x)
        x = self.upA([x, pool3])
        x = self.upB([x, pool2])
        x = self.upC([x, pool1])
        x = self.upD([x, conv1])
        x = self.convB(x)

        return x

# %% [markdown]
# ## Combining Encoder and Decoder

# %%
class DenseDepth(Model):
    def __init__(self):
        super(DenseDepth, self).__init__()
        
        self.encoder = Encoder()
        self.decoder = Decoder(filters=int(self.encoder.layers[-1].output[0].shape[-1] // 2))
    
    def call(self, inputs):
        x = self.encoder(inputs)
        x = self.decoder(x)

        return x

# %% [markdown]
# # Data Loader

# %%
import tensorflow as tf

from sklearn.utils import shuffle

class DataLoader():
    def __init__(self, csv_file='/content/data/nyu2_train.csv', DEBUG=False, NUMBER_DATA=None, split_ratio=5):
        self.shape_rgb = (480, 640, 3)
        self.shape_depth = (240, 320, 1)
        self.split_ratio = split_ratio
        self.read_data(csv_file, DEBUG=DEBUG, num_images=NUMBER_DATA)

    def nyu_resize(self, img, resolution=480, padding=6):
        from skimage.transform import resize
        return resize(img, (resolution, int(resolution*4/3)), preserve_range=True, mode='reflect', anti_aliasing=True )

    def read_data(self, csv_file, DEBUG=False, num_images=None):
        csv = open(csv_file, 'r').read()
        datalist = list((row.split(',') for row in (csv).split('\n') if len(row) > 0))

        datalist = shuffle(datalist, random_state=10)

        if num_images is None:
            num_images = len(datalist)

        if DEBUG:
            num_images = 10
        
        split_pt = int(num_images * (self.split_ratio - 1) / self.split_ratio)
        train = datalist[0:split_pt]
        test = datalist[split_pt:num_images]

        self.train_filenames = [i[0] for i in train]
        self.train_labels = [i[1] for i in train]

        self.test_filenames = [i[0] for i in test]
        self.test_labels = [i[1] for i in test]

    def _parse_function(self, filename, label): 
        # Read images from disk
        image_decoded = tf.image.decode_jpeg(tf.io.read_file(filename))
        depth_resized = tf.image.resize(tf.image.decode_jpeg(tf.io.read_file(label)), [self.shape_depth[0], self.shape_depth[1]])

        # Format
        rgb = tf.image.convert_image_dtype(image_decoded, dtype=tf.float32)
        depth = tf.image.convert_image_dtype(depth_resized / 255.0, dtype=tf.float32)
        
        # Normalize the depth values (in cm)
        depth = 1000 / tf.clip_by_value(depth * 1000, 10, 1000)

        return rgb, depth

    def get_batched_dataset(self, batch_size):
        train_data = tf.data.Dataset.from_tensor_slices((self.train_filenames, self.train_labels)) \
                        .shuffle(buffer_size=len(self.train_filenames), reshuffle_each_iteration=True) \
                        .repeat() \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)

        test_data = tf.data.Dataset.from_tensor_slices((self.test_filenames, self.test_labels)) \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)
                    
        return train_data, test_data

# %% [markdown]
# # Train

# %%
import math

batch_size = 8
learning_rate = 0.0001
c_split_ratio = 5

# Max total batches: 6336 at batch_size=8
## Keep train_batch_num higher to not let model overfit
train_batch_num = 5000

def get_num_images(train_batch_num):
    num_images = int((batch_size * train_batch_num) * (c_split_ratio / (c_split_ratio-1)))
    return num_images

num_images = get_num_images(train_batch_num)
print(num_images)
test_batch_num = math.ceil((num_images - train_batch_num * batch_size) * 1.0 / batch_size)
print(test_batch_num)

if test_batch_num + train_batch_num > 6300:
    print("TF Warning")
# Out:
# 50000
# 1250

# %%
dl = DataLoader(csv_file='/content/data/nyu2_train.csv', NUMBER_DATA=num_images)
train_generator, val_generator = dl.get_batched_dataset(batch_size)

# %%
os.chdir(DATA_PATH)

model = DenseDepth()
model.compile(loss=depth_loss, 
              optimizer=tf.keras.optimizers.Adam(lr=learning_rate, amsgrad=True))s

checkpoint_path = SAVE_PATH + "training/DenseDepth.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
                    checkpoint_path, save_weights_only=False, verbose=1,
                    save_best_only=True)

EPOCHS = 200
train_steps = 50
val_steps = 10

es_patience = EPOCHS//10
early_stop = tf.keras.callbacks.EarlyStopping(
                    patience=es_patience,
                    restore_best_weights=True)

history = model.fit(train_generator, epochs=EPOCHS, steps_per_epoch=train_steps, 
                    validation_data=val_generator, validation_steps=val_steps, 
                    #validation_split=0.2,
                    shuffle=True, 
                    callbacks=[cp_callback], 
                    verbose=2)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59
# Epoch 1/200
#
# Epoch 00001: val_loss improved from inf to 0.30629, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 31s - loss: 0.3287 - val_loss: 0.3063
# Epoch 2/200
#
# Epoch 00002: val_loss improved from 0.30629 to 0.29230, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.2406 - val_loss: 0.2923
# Epoch 3/200
#
# Epoch 00003: val_loss improved from 0.29230 to 0.27512, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.2246 - val_loss: 0.2751
# Epoch 4/200
#
# Epoch 00004: val_loss improved from 0.27512 to 0.26908, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.2020 - val_loss: 0.2691
# Epoch 5/200
#
# Epoch 00005: val_loss improved from 0.26908 to 0.20374, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1963 - val_loss: 0.2037
# Epoch 6/200
#
# Epoch 00006: val_loss did not improve from 0.20374
# 50/50 - 27s - loss: 0.1876 - val_loss: 0.2059
# Epoch 7/200
#
# Epoch 00007: val_loss improved from 0.20374 to 0.18287, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1871 - val_loss: 0.1829
# Epoch 8/200
#
# Epoch 00008: val_loss improved from 0.18287 to 0.17743, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1756 - val_loss: 0.1774
# Epoch 9/200
#
# Epoch 00009: val_loss improved from 0.17743 to 0.17127, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1824 - val_loss: 0.1713
# Epoch 10/200
#
# Epoch 00010: val_loss did not improve from 0.17127
# 50/50 - 27s - loss: 0.1694 - val_loss: 0.1729
# Epoch 11/200
#
# Epoch 00011: val_loss did not improve from 0.17127
# 50/50 - 27s - loss: 0.1726 - val_loss: 0.2095
# Epoch 12/200
#
# Epoch 00012: val_loss improved from 0.17127 to 0.17048, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 29s - loss: 0.1678 - val_loss: 0.1705
# Epoch 13/200
#
# Epoch 00013: val_loss improved from 0.17048 to 0.16704, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1651 - val_loss: 0.1670
# Epoch 14/200
#
# Epoch 00014: val_loss did not improve from 0.16704
# 50/50 - 27s - loss: 0.1610 - val_loss: 0.1901
# Epoch 15/200
#
# Epoch 00015: val_loss did not improve from 0.16704
# 50/50 - 27s - loss: 0.1617 - val_loss: 0.1937
# Epoch 16/200
#
# Epoch 00016: val_loss improved from 0.16704 to 0.16609, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1693 - val_loss: 0.1661
# Epoch 17/200
#
# Epoch 00017: val_loss improved from 0.16609 to 0.16177, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1644 - val_loss: 0.1618
# Epoch 18/200
#
# Epoch 00018: val_loss improved from 0.16177 to 0.15348, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1526 - val_loss: 0.1535
# Epoch 19/200
#
# Epoch 00019: val_loss did not improve from 0.15348
# 50/50 - 27s - loss: 0.1650 - val_loss: 0.1569
# Epoch 20/200
#
# Epoch 00020: val_loss did not improve from 0.15348
# 50/50 - 27s - loss: 0.1634 - val_loss: 0.1599
# Epoch 21/200
#
# Epoch 00021: val_loss did not improve from 0.15348
# 50/50 - 27s - loss: 0.1643 - val_loss: 0.1703
# Epoch 22/200
#
# Epoch 00022: val_loss improved from 0.15348 to 0.15237, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1563 - val_loss: 0.1524
# Epoch 23/200
#
# Epoch 00023: val_loss did not improve from 0.15237
# 50/50 - 27s - loss: 0.1527 - val_loss: 0.1752
# Epoch 24/200
#
# Epoch 00024: val_loss did not improve from 0.15237
# 50/50 - 27s - loss: 0.1508 - val_loss: 0.1842
# Epoch 25/200
#
# Epoch 00025: val_loss improved from 0.15237 to 0.14939, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1422 - val_loss: 0.1494
# Epoch 26/200
#
# Epoch 00026: val_loss did not improve from 0.14939
# 50/50 - 27s - loss: 0.1532 - val_loss: 0.1558
# Epoch 27/200
#
# Epoch 00027: val_loss improved from 0.14939 to 0.14544, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1457 - val_loss: 0.1454
# Epoch 28/200
#
# Epoch 00028: val_loss did not improve from 0.14544
# 50/50 - 27s - loss: 0.1560 - val_loss: 0.1500
# Epoch 29/200
#
# Epoch 00029: val_loss improved from 0.14544 to 0.14127, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1500 - val_loss: 0.1413
# Epoch 30/200
#
# Epoch 00030: val_loss did not improve from 0.14127
# 50/50 - 27s - loss: 0.1483 - val_loss: 0.1581
# Epoch 31/200
#
# Epoch 00031: val_loss did not improve from 0.14127
# 50/50 - 27s - loss: 0.1389 - val_loss: 0.1485
# Epoch 32/200
#
# Epoch 00032: val_loss did not improve from 0.14127
# 50/50 - 27s - loss: 0.1369 - val_loss: 0.1649
# Epoch 33/200
#
# Epoch 00033: val_loss improved from 0.14127 to 0.13973, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1457 - val_loss: 0.1397
# Epoch 34/200
#
# Epoch 00034: val_loss did not improve from 0.13973
# 50/50 - 27s - loss: 0.1409 - val_loss: 0.1412
# Epoch 35/200
#
# Epoch 00035: val_loss improved from 0.13973 to 0.13648, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1405 - val_loss: 0.1365
# Epoch 36/200
#
# Epoch 00036: val_loss did not improve from 0.13648
# 50/50 - 27s - loss: 0.1352 - val_loss: 0.1467
# Epoch 37/200
#
# Epoch 00037: val_loss did not improve from 0.13648
# 50/50 - 27s - loss: 0.1406 - val_loss: 0.1401
# Epoch 38/200
#
# Epoch 00038: val_loss did not improve from 0.13648
# 50/50 - 27s - loss: 0.1380 - val_loss: 0.1388
# Epoch 39/200
#
# Epoch 00039: val_loss did not improve from 0.13648
# 50/50 - 27s - loss: 0.1346 - val_loss: 0.1378
# Epoch 40/200
#
# Epoch 00040: val_loss did not improve from 0.13648
# 50/50 - 27s - loss: 0.1415 - val_loss: 0.1411
# Epoch 41/200
#
# Epoch 00041: val_loss did not improve from 0.13648
# 50/50 - 27s - loss: 0.1313 - val_loss: 0.1488
# Epoch 42/200
#
# Epoch 00042: val_loss improved from 0.13648 to 0.13224, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1343 - val_loss: 0.1322
# Epoch 43/200
#
# Epoch 00043: val_loss did not improve from 0.13224
# 50/50 - 27s - loss: 0.1278 - val_loss: 0.1339
# Epoch 44/200
#
# Epoch 00044: val_loss improved from 0.13224 to 0.13152, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1262 - val_loss: 0.1315
# Epoch 45/200
#
# Epoch 00045: val_loss did not improve from 0.13152
# 50/50 - 27s - loss: 0.1322 - val_loss: 0.1482
# Epoch 46/200
#
# Epoch 00046: val_loss improved from 0.13152 to 0.12794, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1272 - val_loss: 0.1279
# Epoch 47/200
#
# Epoch 00047: val_loss improved from 0.12794 to 0.12777, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1251 - val_loss: 0.1278
# Epoch 48/200
#
# Epoch 00048: val_loss did not improve from 0.12777
# 50/50 - 27s - loss: 0.1331 - val_loss: 0.1302
# Epoch 49/200
#
# Epoch 00049: val_loss did not improve from 0.12777
# 50/50 - 27s - loss: 0.1369 - val_loss: 0.1352
# Epoch 50/200
#
# Epoch 00050: val_loss did not improve from 0.12777
# 50/50 - 27s - loss: 0.1294 - val_loss: 0.1287
# Epoch 51/200
#
# Epoch 00051: val_loss did not improve from 0.12777
# 50/50 - 27s - loss: 0.1307 - val_loss: 0.1351
# Epoch 52/200
#
# Epoch 00052: val_loss did not improve from 0.12777
# 50/50 - 27s - loss: 0.1257 - val_loss: 0.1298
# Epoch 53/200
#
# Epoch 00053: val_loss did not improve from 0.12777
# 50/50 - 27s - loss: 0.1194 - val_loss: 0.1279
# Epoch 54/200
#
# Epoch 00054: val_loss improved from 0.12777 to 0.12601, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1249 - val_loss: 0.1260
# Epoch 55/200
#
# Epoch 00055: val_loss did not improve from 0.12601
# 50/50 - 27s - loss: 0.1204 - val_loss: 0.1317
# Epoch 56/200
#
# Epoch 00056: val_loss improved from 0.12601 to 0.12586, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1218 - val_loss: 0.1259
# Epoch 57/200
#
# Epoch 00057: val_loss did not improve from 0.12586
# 50/50 - 27s - loss: 0.1234 - val_loss: 0.1333
# Epoch 58/200
#
# Epoch 00058: val_loss improved from 0.12586 to 0.12034, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1238 - val_loss: 0.1203
# Epoch 59/200
#
# Epoch 00059: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1252 - val_loss: 0.1283
# Epoch 60/200
#
# Epoch 00060: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1215 - val_loss: 0.1309
# Epoch 61/200
#
# Epoch 00061: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1173 - val_loss: 0.1245
# Epoch 62/200
#
# Epoch 00062: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1209 - val_loss: 0.1232
# Epoch 63/200
#
# Epoch 00063: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1209 - val_loss: 0.1251
# Epoch 64/200
#
# Epoch 00064: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1182 - val_loss: 0.1245
# Epoch 65/200
#
# Epoch 00065: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1266 - val_loss: 0.1208
# Epoch 66/200
#
# Epoch 00066: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1233 - val_loss: 0.1272
# Epoch 67/200
#
# Epoch 00067: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1156 - val_loss: 0.1214
# Epoch 68/200
#
# Epoch 00068: val_loss did not improve from 0.12034
# 50/50 - 27s - loss: 0.1182 - val_loss: 0.1235
# Epoch 69/200
#
# Epoch 00069: val_loss improved from 0.12034 to 0.12002, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1194 - val_loss: 0.1200
# Epoch 70/200
#
# Epoch 00070: val_loss did not improve from 0.12002
# 50/50 - 27s - loss: 0.1129 - val_loss: 0.1221
# Epoch 71/200
#
# Epoch 00071: val_loss did not improve from 0.12002
# 50/50 - 27s - loss: 0.1213 - val_loss: 0.1404
# Epoch 72/200
#
# Epoch 00072: val_loss improved from 0.12002 to 0.11611, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 29s - loss: 0.1224 - val_loss: 0.1161
# Epoch 73/200
#
# Epoch 00073: val_loss did not improve from 0.11611
# 50/50 - 27s - loss: 0.1165 - val_loss: 0.1203
# Epoch 74/200
#
# Epoch 00074: val_loss did not improve from 0.11611
# 50/50 - 27s - loss: 0.1164 - val_loss: 0.1215
# Epoch 75/200
#
# Epoch 00075: val_loss did not improve from 0.11611
# 50/50 - 27s - loss: 0.1143 - val_loss: 0.1200
# Epoch 76/200
#
# Epoch 00076: val_loss did not improve from 0.11611
# 50/50 - 27s - loss: 0.1175 - val_loss: 0.1258
# Epoch 77/200
#
# Epoch 00077: val_loss did not improve from 0.11611
# 50/50 - 27s - loss: 0.1166 - val_loss: 0.1168
# Epoch 78/200
#
# Epoch 00078: val_loss did not improve from 0.11611
# 50/50 - 27s - loss: 0.1123 - val_loss: 0.1271
# Epoch 79/200
#
# Epoch 00079: val_loss did not improve from 0.11611
# 50/50 - 27s - loss: 0.1216 - val_loss: 0.1206
# Epoch 80/200
#
# Epoch 00080: val_loss did not improve from 0.11611
# 50/50 - 27s - loss: 0.1112 - val_loss: 0.1181
# Epoch 81/200
#
# Epoch 00081: val_loss improved from 0.11611 to 0.11190, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1156 - val_loss: 0.1119
# Epoch 82/200
#
# Epoch 00082: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1154 - val_loss: 0.1156
# Epoch 83/200
#
# Epoch 00083: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1157 - val_loss: 0.1192
# Epoch 84/200
#
# Epoch 00084: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1102 - val_loss: 0.1187
# Epoch 85/200
#
# Epoch 00085: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1085 - val_loss: 0.1226
# Epoch 86/200
#
# Epoch 00086: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1140 - val_loss: 0.1181
# Epoch 87/200
#
# Epoch 00087: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1111 - val_loss: 0.1189
# Epoch 88/200
#
# Epoch 00088: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1161 - val_loss: 0.1192
# Epoch 89/200
#
# Epoch 00089: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1176 - val_loss: 0.1167
# Epoch 90/200
#
# Epoch 00090: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1104 - val_loss: 0.1219
# Epoch 91/200
#
# Epoch 00091: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1109 - val_loss: 0.1233
# Epoch 92/200
#
# Epoch 00092: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1135 - val_loss: 0.1122
# Epoch 93/200
#
# Epoch 00093: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1115 - val_loss: 0.1179
# Epoch 94/200
#
# Epoch 00094: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1091 - val_loss: 0.1166
# Epoch 95/200
#
# Epoch 00095: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1094 - val_loss: 0.1155
# Epoch 96/200
#
# Epoch 00096: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1089 - val_loss: 0.1149
# Epoch 97/200
#
# Epoch 00097: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1121 - val_loss: 0.1120
# Epoch 98/200
#
# Epoch 00098: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1103 - val_loss: 0.1131
# Epoch 99/200
#
# Epoch 00099: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1109 - val_loss: 0.1178
# Epoch 100/200
#
# Epoch 00100: val_loss did not improve from 0.11190
# 50/50 - 27s - loss: 0.1112 - val_loss: 0.1174
# Epoch 101/200
#
# Epoch 00101: val_loss improved from 0.11190 to 0.10815, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1098 - val_loss: 0.1081
# Epoch 102/200
#
# Epoch 00102: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1095 - val_loss: 0.1147
# Epoch 103/200
#
# Epoch 00103: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1038 - val_loss: 0.1113
# Epoch 104/200
#
# Epoch 00104: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1103 - val_loss: 0.1152
# Epoch 105/200
#
# Epoch 00105: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1068 - val_loss: 0.1103
# Epoch 106/200
#
# Epoch 00106: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1060 - val_loss: 0.1204
# Epoch 107/200
#
# Epoch 00107: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1037 - val_loss: 0.1190
# Epoch 108/200
#
# Epoch 00108: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1051 - val_loss: 0.1122
# Epoch 109/200
#
# Epoch 00109: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1054 - val_loss: 0.1105
# Epoch 110/200
#
# Epoch 00110: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1023 - val_loss: 0.1094
# Epoch 111/200
#
# Epoch 00111: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1048 - val_loss: 0.1112
# Epoch 112/200
#
# Epoch 00112: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1049 - val_loss: 0.1092
# Epoch 113/200
#
# Epoch 00113: val_loss did not improve from 0.10815
# 50/50 - 27s - loss: 0.1017 - val_loss: 0.1180
# Epoch 114/200
#
# Epoch 00114: val_loss improved from 0.10815 to 0.10557, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0993 - val_loss: 0.1056
# Epoch 115/200
#
# Epoch 00115: val_loss improved from 0.10557 to 0.10533, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0997 - val_loss: 0.1053
# Epoch 116/200
#
# Epoch 00116: val_loss did not improve from 0.10533
# 50/50 - 27s - loss: 0.1049 - val_loss: 0.1172
# Epoch 117/200
#
# Epoch 00117: val_loss did not improve from 0.10533
# 50/50 - 27s - loss: 0.1047 - val_loss: 0.1069
# Epoch 118/200
#
# Epoch 00118: val_loss did not improve from 0.10533
# 50/50 - 27s - loss: 0.1041 - val_loss: 0.1093
# Epoch 119/200
#
# Epoch 00119: val_loss did not improve from 0.10533
# 50/50 - 27s - loss: 0.1056 - val_loss: 0.1092
# Epoch 120/200
#
# Epoch 00120: val_loss improved from 0.10533 to 0.10527, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1054 - val_loss: 0.1053
# Epoch 121/200
#
# Epoch 00121: val_loss did not improve from 0.10527
# 50/50 - 27s - loss: 0.1117 - val_loss: 0.1068
# Epoch 122/200
#
# Epoch 00122: val_loss did not improve from 0.10527
# 50/50 - 27s - loss: 0.1079 - val_loss: 0.1107
# Epoch 123/200
#
# Epoch 00123: val_loss did not improve from 0.10527
# 50/50 - 27s - loss: 0.1026 - val_loss: 0.1111
# Epoch 124/200
#
# Epoch 00124: val_loss did not improve from 0.10527
# 50/50 - 27s - loss: 0.1013 - val_loss: 0.1097
# Epoch 125/200
#
# Epoch 00125: val_loss did not improve from 0.10527
# 50/50 - 27s - loss: 0.0996 - val_loss: 0.1062
# Epoch 126/200
#
# Epoch 00126: val_loss did not improve from 0.10527
# 50/50 - 27s - loss: 0.1063 - val_loss: 0.1076
# Epoch 127/200
#
# Epoch 00127: val_loss did not improve from 0.10527
# 50/50 - 27s - loss: 0.0990 - val_loss: 0.1121
# Epoch 128/200
#
# Epoch 00128: val_loss improved from 0.10527 to 0.10511, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1053 - val_loss: 0.1051
# Epoch 129/200
#
# Epoch 00129: val_loss did not improve from 0.10511
# 50/50 - 27s - loss: 0.0983 - val_loss: 0.1072
# Epoch 130/200
#
# Epoch 00130: val_loss did not improve from 0.10511
# 50/50 - 27s - loss: 0.0996 - val_loss: 0.1060
# Epoch 131/200
#
# Epoch 00131: val_loss did not improve from 0.10511
# 50/50 - 27s - loss: 0.0994 - val_loss: 0.1053
# Epoch 132/200
#
# Epoch 00132: val_loss improved from 0.10511 to 0.10493, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1007 - val_loss: 0.1049
# Epoch 133/200
#
# Epoch 00133: val_loss did not improve from 0.10493
# 50/50 - 27s - loss: 0.1013 - val_loss: 0.1093
# Epoch 134/200
#
# Epoch 00134: val_loss did not improve from 0.10493
# 50/50 - 27s - loss: 0.1021 - val_loss: 0.1053
# Epoch 135/200
#
# Epoch 00135: val_loss improved from 0.10493 to 0.10335, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1029 - val_loss: 0.1033
# Epoch 136/200
#
# Epoch 00136: val_loss improved from 0.10335 to 0.10280, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0999 - val_loss: 0.1028
# Epoch 137/200
#
# Epoch 00137: val_loss did not improve from 0.10280
# 50/50 - 27s - loss: 0.1038 - val_loss: 0.1187
# Epoch 138/200
#
# Epoch 00138: val_loss did not improve from 0.10280
# 50/50 - 27s - loss: 0.1027 - val_loss: 0.1113
# Epoch 139/200
#
# Epoch 00139: val_loss did not improve from 0.10280
# 50/50 - 27s - loss: 0.0951 - val_loss: 0.1035
# Epoch 140/200
#
# Epoch 00140: val_loss did not improve from 0.10280
# 50/50 - 27s - loss: 0.0988 - val_loss: 0.1031
# Epoch 141/200
#
# Epoch 00141: val_loss did not improve from 0.10280
# 50/50 - 27s - loss: 0.1018 - val_loss: 0.1139
# Epoch 142/200
#
# Epoch 00142: val_loss improved from 0.10280 to 0.10257, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.1025 - val_loss: 0.1026
# Epoch 143/200
#
# Epoch 00143: val_loss did not improve from 0.10257
# 50/50 - 27s - loss: 0.0964 - val_loss: 0.1034
# Epoch 144/200
#
# Epoch 00144: val_loss improved from 0.10257 to 0.10257, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0950 - val_loss: 0.1026
# Epoch 145/200
#
# Epoch 00145: val_loss did not improve from 0.10257
# 50/50 - 27s - loss: 0.0988 - val_loss: 0.1108
# Epoch 146/200
#
# Epoch 00146: val_loss improved from 0.10257 to 0.10217, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0960 - val_loss: 0.1022
# Epoch 147/200
#
# Epoch 00147: val_loss improved from 0.10217 to 0.10151, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0957 - val_loss: 0.1015
# Epoch 148/200
#
# Epoch 00148: val_loss did not improve from 0.10151
# 50/50 - 27s - loss: 0.0991 - val_loss: 0.1015
# Epoch 149/200
#
# Epoch 00149: val_loss did not improve from 0.10151
# 50/50 - 27s - loss: 0.1001 - val_loss: 0.1020
# Epoch 150/200
#
# Epoch 00150: val_loss did not improve from 0.10151
# 50/50 - 27s - loss: 0.0989 - val_loss: 0.1073
# Epoch 151/200
#
# Epoch 00151: val_loss did not improve from 0.10151
# 50/50 - 27s - loss: 0.1008 - val_loss: 0.1031
# Epoch 152/200
#
# Epoch 00152: val_loss did not improve from 0.10151
# 50/50 - 27s - loss: 0.0981 - val_loss: 0.1039
# Epoch 153/200
#
# Epoch 00153: val_loss did not improve from 0.10151
# 50/50 - 27s - loss: 0.0933 - val_loss: 0.1038
# Epoch 154/200
#
# Epoch 00154: val_loss did not improve from 0.10151
# 50/50 - 27s - loss: 0.0989 - val_loss: 0.1018
# Epoch 155/200
#
# Epoch 00155: val_loss did not improve from 0.10151
# 50/50 - 27s - loss: 0.0957 - val_loss: 0.1050
# Epoch 156/200
#
# Epoch 00156: val_loss improved from 0.10151 to 0.10118, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0970 - val_loss: 0.1012
# Epoch 157/200
#
# Epoch 00157: val_loss improved from 0.10118 to 0.10046, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0968 - val_loss: 0.1005
# Epoch 158/200
#
# Epoch 00158: val_loss did not improve from 0.10046
# 50/50 - 27s - loss: 0.0987 - val_loss: 0.1030
# Epoch 159/200
#
# Epoch 00159: val_loss improved from 0.10046 to 0.09920, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0959 - val_loss: 0.0992
# Epoch 160/200
#
# Epoch 00160: val_loss did not improve from 0.09920
# 50/50 - 27s - loss: 0.0990 - val_loss: 0.1034
# Epoch 161/200
#
# Epoch 00161: val_loss did not improve from 0.09920
# 50/50 - 27s - loss: 0.0933 - val_loss: 0.1015
# Epoch 162/200
#
# Epoch 00162: val_loss improved from 0.09920 to 0.09893, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0968 - val_loss: 0.0989
# Epoch 163/200
#
# Epoch 00163: val_loss did not improve from 0.09893
# 50/50 - 27s - loss: 0.0978 - val_loss: 0.1005
# Epoch 164/200
#
# Epoch 00164: val_loss did not improve from 0.09893
# 50/50 - 27s - loss: 0.0963 - val_loss: 0.1023
# Epoch 165/200
#
# Epoch 00165: val_loss did not improve from 0.09893
# 50/50 - 27s - loss: 0.0998 - val_loss: 0.1007
# Epoch 166/200
#
# Epoch 00166: val_loss did not improve from 0.09893
# 50/50 - 27s - loss: 0.0926 - val_loss: 0.1009
# Epoch 167/200
#
# Epoch 00167: val_loss did not improve from 0.09893
# 50/50 - 27s - loss: 0.0929 - val_loss: 0.0997
# Epoch 168/200
#
# Epoch 00168: val_loss did not improve from 0.09893
# 50/50 - 27s - loss: 0.0943 - val_loss: 0.1044
# Epoch 169/200
#
# Epoch 00169: val_loss did not improve from 0.09893
# 50/50 - 27s - loss: 0.0976 - val_loss: 0.0990
# Epoch 170/200
#
# Epoch 00170: val_loss improved from 0.09893 to 0.09844, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0927 - val_loss: 0.0984
# Epoch 171/200
#
# Epoch 00171: val_loss did not improve from 0.09844
# 50/50 - 27s - loss: 0.0972 - val_loss: 0.0986
# Epoch 172/200
#
# Epoch 00172: val_loss improved from 0.09844 to 0.09736, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0959 - val_loss: 0.0974
# Epoch 173/200
#
# Epoch 00173: val_loss did not improve from 0.09736
# 50/50 - 27s - loss: 0.0950 - val_loss: 0.1004
# Epoch 174/200
#
# Epoch 00174: val_loss did not improve from 0.09736
# 50/50 - 27s - loss: 0.0963 - val_loss: 0.0992
# Epoch 175/200
#
# Epoch 00175: val_loss did not improve from 0.09736
# 50/50 - 27s - loss: 0.0955 - val_loss: 0.1007
# Epoch 176/200
#
# Epoch 00176: val_loss did not improve from 0.09736
# 50/50 - 27s - loss: 0.0969 - val_loss: 0.1008
# Epoch 177/200
#
# Epoch 00177: val_loss did not improve from 0.09736
# 50/50 - 27s - loss: 0.0948 - val_loss: 0.0985
# Epoch 178/200
#
# Epoch 00178: val_loss improved from 0.09736 to 0.09720, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 29s - loss: 0.0923 - val_loss: 0.0972
# Epoch 179/200
#
# Epoch 00179: val_loss did not improve from 0.09720
# 50/50 - 27s - loss: 0.1010 - val_loss: 0.1016
# Epoch 180/200
#
# Epoch 00180: val_loss improved from 0.09720 to 0.09715, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0907 - val_loss: 0.0972
# Epoch 181/200
#
# Epoch 00181: val_loss improved from 0.09715 to 0.09710, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0946 - val_loss: 0.0971
# Epoch 182/200
#
# Epoch 00182: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0908 - val_loss: 0.0997
# Epoch 183/200
#
# Epoch 00183: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0964 - val_loss: 0.0979
# Epoch 184/200
#
# Epoch 00184: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0927 - val_loss: 0.0972
# Epoch 185/200
#
# Epoch 00185: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0910 - val_loss: 0.1009
# Epoch 186/200
#
# Epoch 00186: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0946 - val_loss: 0.0993
# Epoch 187/200
#
# Epoch 00187: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0913 - val_loss: 0.1026
# Epoch 188/200
#
# Epoch 00188: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0938 - val_loss: 0.0984
# Epoch 189/200
#
# Epoch 00189: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0968 - val_loss: 0.0992
# Epoch 190/200
#
# Epoch 00190: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0948 - val_loss: 0.0980
# Epoch 191/200
#
# Epoch 00191: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0936 - val_loss: 0.1006
# Epoch 192/200
#
# Epoch 00192: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0930 - val_loss: 0.1001
# Epoch 193/200
#
# Epoch 00193: val_loss did not improve from 0.09710
# 50/50 - 27s - loss: 0.0957 - val_loss: 0.0985
# Epoch 194/200
#
# Epoch 00194: val_loss improved from 0.09710 to 0.09656, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0922 - val_loss: 0.0966
# Epoch 195/200
#
# Epoch 00195: val_loss did not improve from 0.09656
# 50/50 - 27s - loss: 0.0927 - val_loss: 0.1007
# Epoch 196/200
#
# Epoch 00196: val_loss did not improve from 0.09656
# 50/50 - 27s - loss: 0.0925 - val_loss: 0.0969
# Epoch 197/200
#
# Epoch 00197: val_loss improved from 0.09656 to 0.09583, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0927 - val_loss: 0.0958
# Epoch 198/200
#
# Epoch 00198: val_loss improved from 0.09583 to 0.09582, saving model to /content/training/DenseDepth.ckpt
# 50/50 - 28s - loss: 0.0925 - val_loss: 0.0958
# Epoch 199/200
#
# Epoch 00199: val_loss did not improve from 0.09582
# 50/50 - 27s - loss: 0.0932 - val_loss: 0.0997
# Epoch 200/200
#
# Epoch 00200: val_loss did not improve from 0.09582
# 50/50 - 27s - loss: 0.0939 - val_loss: 0.1067

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 8))

plt.plot(epochs_range, loss, label='Training loss')
plt.plot(epochs_range, val_loss, label='Validation loss')
plt.legend(loc='upper right')
plt.title('Training and Validation loss')
os.chdir(SAVE_PATH)
plt.savefig('loss.png')

# %% [markdown]
# # Test Helper functions

# %% [markdown]
# ## Utils

# %%
import cv2
import numpy as np

def DepthNorm(x, maxDepth):
    return maxDepth / x

def predict(model, images, minDepth=10, maxDepth=1000, batch_size=2):
    # Support multiple RGBs, one RGB image, even grayscale 
    if len(images.shape) < 3: images = np.stack((images,images,images), axis=2)
    if len(images.shape) < 4: images = images.reshape((1, images.shape[0], images.shape[1], images.shape[2]))
    # Compute predictions
    predictions = model.predict(images, batch_size=batch_size)
    # Put in expected range
    return np.clip(DepthNorm(predictions, maxDepth=maxDepth), minDepth, maxDepth) / maxDepth

# %% [markdown]
# # Test

# %%
os.chdir(SAVE_PATH)
print('Loading model...')
model = DenseDepth()
checkpoint_path = "training/DenseDepth.ckpt"
model.load_weights(checkpoint_path)
print('Model weights loaded.')
# Out:
# Loading model...
# Model weights loaded.

# %%
count = 5

os.chdir(SAVE_PATH)
path_pre = DATA_PATH + 'data/nyu2_test/'
files = [f for f in os.listdir(path_pre) if f.split('_')[1] == 'colors.png']
(fig, axes) = plt.subplots(nrows=count, ncols=3, figsize=(15,15))
i = 0
for f in files:
    file_id = f.split('_')[0]
    depth_file = file_id + '_depth.png'
    img = cv2.imread(path_pre + f, cv2.IMREAD_COLOR)
    axes[i][0].imshow(img)
    axes[i][0].set_title('OG')

    img = np.clip(img/255, 0, 1)
    img = predict(model, img, batch_size=1)
    axes[i][2].imshow(img[0,:,:,0], cmap='plasma')
    axes[i][2].set_title('Predicted')

    img = cv2.imread(path_pre + depth_file, cv2.IMREAD_ANYDEPTH)
    axes[i][1].imshow(img, cmap='plasma')
    axes[i][1].set_title('GT')
    
    if i == count-1:
        break
    else:
        i += 1

plt.savefig('result.png')
