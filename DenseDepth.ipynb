# %% [markdown]
# # Download Train and Test data

# %%
import os
DATA_PATH = '/content/'
os.chdir(DATA_PATH)

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_data.zip
# !unzip nyu_data.zip

# %%
#!wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu_test.zip

# %% [markdown]
# # Set Paths

# %%
import os
DATA_PATH = '/content/'
SAVE_PATH = '/content/'
os.chdir(SAVE_PATH)
os.getcwd()
# Out:
# '/content'

# %%
try:
    # %tensorflow_version 2.x
except:
    pass
import tensorflow as tf
import tensorflow.keras.backend as K
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Loss function

# %%
def depth_loss(y_true, y_pred, theta=0.1, maxDepthVal=1000.0/10.0):
    # Point-wise depth
    l_depth = K.mean(K.abs(y_pred - y_true), axis=-1)

    # Edges
    dy_true, dx_true = tf.image.image_gradients(y_true)
    dy_pred, dx_pred = tf.image.image_gradients(y_pred)
    l_edges = K.mean(K.abs(dy_pred - dy_true) + K.abs(dx_pred - dx_true), axis=-1)

    # Structural similarity (SSIM) index
    l_ssim = K.clip((1 - tf.image.ssim(y_true, y_pred, maxDepthVal)) * 0.5, 0, 1)

    # Weights
    w1 = 1.0
    w2 = 1.0
    w3 = theta

    return (w1 * l_ssim) + (w2 * K.mean(l_edges)) + (w3 * K.mean(l_depth))

# %% [markdown]
# # Define Model

# %% [markdown]
# ## Upscale block

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D, UpSampling2D, LeakyReLU, Concatenate
from tensorflow.keras.applications import DenseNet169

class UpscaleBlock(Model):
    def __init__(self, filters):
        # call parent constructor
        super(UpscaleBlock, self).__init__()
        ALPHA = 0.2

        self.upscl = UpSampling2D(interpolation='bilinear')
        self.cncat = Concatenate()

        self.convA = Conv2D(filters, (3, 3) , padding='same')
        self.reluA = LeakyReLU(alpha=ALPHA)  

        self.convB = Conv2D(filters, (3, 3), padding='same')
        self.reluB = LeakyReLU(alpha=ALPHA)
    
    def call(self, inputs):
        x = self.upscl(inputs[0])
        x = self.cncat([x, inputs[1]])
        
        x = self.convA(x)
        x = self.reluA(x)

        x = self.convB(x)
        x = self.reluB(x)

        return x

# %% [markdown]
# ## Encode Block

# %%
class Encoder(Model):
    def __init__(self):
        super(Encoder, self).__init__()

        self.base = DenseNet169(input_shape=(None, None, 3), include_top=False)

        outputs = [self.base.outputs[-1]]
        for name in ['pool1', 'pool2_pool', 'pool3_pool', 'conv1/relu']:
            outputs.append(self.base.get_layer(name).output)

        self.encoder = Model(inputs = self.base.inputs, outputs = outputs)       

    def call(self, inputs):
        x = self.encoder(inputs)
        return x

# %% [markdown]
# ## Decode Block

# %%
class Decoder(Model):
    def __init__(self, filters):
        super(Decoder, self).__init__()

        self.convA = Conv2D(filters, (1, 1), padding='same')

        self.upA = UpscaleBlock(filters=filters//2)
        self.upB = UpscaleBlock(filters=filters//4)
        self.upC = UpscaleBlock(filters=filters//8)
        self.upD = UpscaleBlock(filters=filters//16)

        self.convB = Conv2D(1, (3, 3), padding='same')
    
    def call(self, inputs):
        x, pool1, pool2, pool3, conv1 = inputs[0], inputs[1], inputs[2], inputs[3], inputs[4]

        x = self.convA(x)
        x = self.upA([x, pool3])
        x = self.upB([x, pool2])
        x = self.upC([x, pool1])
        x = self.upD([x, conv1])
        x = self.convB(x)

        return x

# %% [markdown]
# ## Combining Encoder and Decoder

# %%
class DenseDepth(Model):
    def __init__(self):
        super(DenseDepth, self).__init__()
        
        self.encoder = Encoder()
        self.decoder = Decoder(filters=int(self.encoder.layers[-1].output[0].shape[-1] // 2))
    
    def call(self, inputs):
        x = self.encoder(inputs)
        x = self.decoder(x)

        return x

# %% [markdown]
# # Data Loader

# %%
import tensorflow as tf

from sklearn.utils import shuffle

class DataLoader():
    def __init__(self, csv_file='/content/data/nyu2_train.csv', DEBUG=False, NUMBER_DATA=None, split_ratio=5):
        self.shape_rgb = (480, 640, 3)
        self.shape_depth = (240, 320, 1)
        self.split_ratio = split_ratio
        self.read_data(csv_file, DEBUG=DEBUG, num_images=NUMBER_DATA)

    def nyu_resize(self, img, resolution=480, padding=6):
        from skimage.transform import resize
        return resize(img, (resolution, int(resolution*4/3)), preserve_range=True, mode='reflect', anti_aliasing=True )

    def read_data(self, csv_file, DEBUG=False, num_images=None):
        csv = open(csv_file, 'r').read()
        datalist = list((row.split(',') for row in (csv).split('\n') if len(row) > 0))

        datalist = shuffle(datalist, random_state=10)

        if num_images is None:
            num_images = len(datalist)

        if DEBUG:
            num_images = 10
        
        split_pt = int(num_images * (self.split_ratio - 1) / self.split_ratio)
        train = datalist[0:split_pt]
        test = datalist[split_pt:num_images]

        self.train_filenames = [i[0] for i in train]
        self.train_labels = [i[1] for i in train]

        self.test_filenames = [i[0] for i in test]
        self.test_labels = [i[1] for i in test]

    def _parse_function(self, filename, label): 
        # Read images from disk
        image_decoded = tf.image.decode_jpeg(tf.io.read_file(filename))
        depth_resized = tf.image.resize(tf.image.decode_jpeg(tf.io.read_file(label)), [self.shape_depth[0], self.shape_depth[1]])

        # Format
        rgb = tf.image.convert_image_dtype(image_decoded, dtype=tf.float32)
        depth = tf.image.convert_image_dtype(depth_resized / 255.0, dtype=tf.float32)
        
        # Normalize the depth values (in cm)
        depth = 1000 / tf.clip_by_value(depth * 1000, 10, 1000)

        return rgb, depth

    def get_batched_dataset(self, batch_size):
        train_data = tf.data.Dataset.from_tensor_slices((self.train_filenames, self.train_labels)) \
                        .shuffle(buffer_size=len(self.train_filenames), reshuffle_each_iteration=True) \
                        .repeat() \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)

        test_data = tf.data.Dataset.from_tensor_slices((self.test_filenames, self.test_labels)) \
                        .map(map_func=self._parse_function) \
                        .batch(batch_size=batch_size)
                    
        return train_data, test_data

# %% [markdown]
# # Train

# %%
import math

batch_size = 8
learning_rate = 0.0001
c_split_ratio = 5

# Max total batches: 6336 at batch_size=8
## Keep train_batch_num higher to not let model overfit
train_batch_num = 200
num_images = int((batch_size * train_batch_num) * (c_split_ratio / (c_split_ratio-1)))
print(num_images)
test_batch_num = math.ceil((num_images - train_batch_num * batch_size) * 1.0 / batch_size)
print(test_batch_num)
# Out:
# 2000
# 50

# %%
dl = DataLoader(csv_file='/content/data/nyu2_train.csv', NUMBER_DATA=num_images)
train_generator, val_generator = dl.get_batched_dataset(batch_size)

# %%
os.chdir(DATA_PATH)

model = DenseDepth()
model.compile(loss=depth_loss, 
              optimizer=tf.keras.optimizers.Adam(lr=learning_rate, amsgrad=True))

checkpoint_path = SAVE_PATH + "training/DenseDepth.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
cp_callback = tf.keras.callbacks.ModelCheckpoint(
                    checkpoint_path, save_weights_only=False, verbose=1,
                    save_best_only=True)

es_patience = 10
early_stop = tf.keras.callbacks.EarlyStopping(
                    patience=es_patience,
                    restore_best_weights=True)

EPOCHS = 100
train_steps = train_batch_num
val_steps = test_batch_num
history = model.fit(train_generator, epochs=EPOCHS, steps_per_epoch=train_steps, 
                    validation_data=val_generator, validation_steps=val_steps, 
                    callbacks=[cp_callback, early_stop], 
                    verbose=2)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.20181, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 116s - loss: 0.2492 - val_loss: 0.2018
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.20181 to 0.16374, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1836 - val_loss: 0.1637
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.16374 to 0.16212, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1680 - val_loss: 0.1621
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.16212 to 0.15226, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1526 - val_loss: 0.1523
# Epoch 5/100
#
# Epoch 00005: val_loss did not improve from 0.15226
# 200/200 - 111s - loss: 0.1471 - val_loss: 0.1608
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 0.15226
# 200/200 - 111s - loss: 0.1413 - val_loss: 0.1530
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.15226 to 0.14375, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1339 - val_loss: 0.1437
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.14375 to 0.13661, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1285 - val_loss: 0.1366
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.13661
# 200/200 - 111s - loss: 0.1247 - val_loss: 0.1379
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.13661 to 0.13253, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1200 - val_loss: 0.1325
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.13253
# 200/200 - 111s - loss: 0.1169 - val_loss: 0.1340
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.13253 to 0.13133, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1129 - val_loss: 0.1313
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.13133 to 0.12914, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1095 - val_loss: 0.1291
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.12914
# 200/200 - 111s - loss: 0.1061 - val_loss: 0.1346
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.12914 to 0.12574, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1023 - val_loss: 0.1257
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 0.12574
# 200/200 - 111s - loss: 0.0993 - val_loss: 0.1312
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.12574 to 0.12346, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.1013 - val_loss: 0.1235
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.12346
# 200/200 - 111s - loss: 0.0983 - val_loss: 0.1260
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.12346 to 0.12112, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0972 - val_loss: 0.1211
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.12112
# 200/200 - 111s - loss: 0.0949 - val_loss: 0.1217
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.12112 to 0.12040, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0941 - val_loss: 0.1204
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.12040 to 0.11977, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0934 - val_loss: 0.1198
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.11977
# 200/200 - 111s - loss: 0.0914 - val_loss: 0.1235
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.11977
# 200/200 - 111s - loss: 0.0900 - val_loss: 0.1209
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.11977 to 0.11686, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0886 - val_loss: 0.1169
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.11686
# 200/200 - 111s - loss: 0.0867 - val_loss: 0.1175
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.11686
# 200/200 - 111s - loss: 0.0852 - val_loss: 0.1177
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.11686
# 200/200 - 111s - loss: 0.0849 - val_loss: 0.1203
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.11686
# 200/200 - 111s - loss: 0.0859 - val_loss: 0.1178
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.11686 to 0.11535, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0833 - val_loss: 0.1154
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.11535
# 200/200 - 111s - loss: 0.0834 - val_loss: 0.1166
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.11535
# 200/200 - 111s - loss: 0.0839 - val_loss: 0.1157
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.11535
# 200/200 - 111s - loss: 0.0830 - val_loss: 0.1161
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.11535
# 200/200 - 111s - loss: 0.0813 - val_loss: 0.1173
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 0.11535 to 0.11505, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0810 - val_loss: 0.1150
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.11505 to 0.11418, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0790 - val_loss: 0.1142
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.11418
# 200/200 - 111s - loss: 0.0797 - val_loss: 0.1155
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.11418
# 200/200 - 111s - loss: 0.0793 - val_loss: 0.1149
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.11418
# 200/200 - 111s - loss: 0.0780 - val_loss: 0.1147
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.11418
# 200/200 - 111s - loss: 0.0776 - val_loss: 0.1178
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 0.11418 to 0.11388, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 113s - loss: 0.0773 - val_loss: 0.1139
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 0.11388 to 0.11261, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0762 - val_loss: 0.1126
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.11261
# 200/200 - 111s - loss: 0.0753 - val_loss: 0.1167
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.11261
# 200/200 - 111s - loss: 0.0757 - val_loss: 0.1138
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.11261
# 200/200 - 111s - loss: 0.0740 - val_loss: 0.1139
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.11261
# 200/200 - 111s - loss: 0.0750 - val_loss: 0.1133
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.11261
# 200/200 - 111s - loss: 0.0747 - val_loss: 0.1168
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 0.11261 to 0.11187, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0736 - val_loss: 0.1119
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.11187
# 200/200 - 111s - loss: 0.0738 - val_loss: 0.1139
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.11187
# 200/200 - 111s - loss: 0.0736 - val_loss: 0.1144
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.11187
# 200/200 - 111s - loss: 0.0730 - val_loss: 0.1136
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.11187
# 200/200 - 111s - loss: 0.0731 - val_loss: 0.1120
# Epoch 53/100
#
# Epoch 00053: val_loss improved from 0.11187 to 0.11164, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0710 - val_loss: 0.1116
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.11164
# 200/200 - 111s - loss: 0.0708 - val_loss: 0.1123
# Epoch 55/100
#
# Epoch 00055: val_loss improved from 0.11164 to 0.11120, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 113s - loss: 0.0710 - val_loss: 0.1112
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.11120
# 200/200 - 111s - loss: 0.0722 - val_loss: 0.1154
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.11120
# 200/200 - 111s - loss: 0.0709 - val_loss: 0.1117
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.11120
# 200/200 - 111s - loss: 0.0705 - val_loss: 0.1136
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.11120
# 200/200 - 111s - loss: 0.0709 - val_loss: 0.1120
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.11120
# 200/200 - 111s - loss: 0.0699 - val_loss: 0.1131
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.11120
# 200/200 - 111s - loss: 0.0685 - val_loss: 0.1147
# Epoch 62/100
#
# Epoch 00062: val_loss improved from 0.11120 to 0.11112, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0694 - val_loss: 0.1111
# Epoch 63/100
#
# Epoch 00063: val_loss improved from 0.11112 to 0.11089, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0687 - val_loss: 0.1109
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.11089
# 200/200 - 111s - loss: 0.0717 - val_loss: 0.1133
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.11089
# 200/200 - 111s - loss: 0.0689 - val_loss: 0.1119
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.11089
# 200/200 - 111s - loss: 0.0694 - val_loss: 0.1130
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.11089
# 200/200 - 111s - loss: 0.0681 - val_loss: 0.1115
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.11089
# 200/200 - 111s - loss: 0.0679 - val_loss: 0.1111
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.11089
# 200/200 - 111s - loss: 0.0680 - val_loss: 0.1138
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.11089
# 200/200 - 111s - loss: 0.0678 - val_loss: 0.1114
# Epoch 71/100
#
# Epoch 00071: val_loss improved from 0.11089 to 0.10973, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0667 - val_loss: 0.1097
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0669 - val_loss: 0.1132
# Epoch 73/100
#
# Epoch 00073: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0668 - val_loss: 0.1126
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0661 - val_loss: 0.1119
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0660 - val_loss: 0.1111
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0662 - val_loss: 0.1123
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0653 - val_loss: 0.1107
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0656 - val_loss: 0.1107
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0654 - val_loss: 0.1104
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0647 - val_loss: 0.1114
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0643 - val_loss: 0.1102
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0635 - val_loss: 0.1109
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0639 - val_loss: 0.1114
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0642 - val_loss: 0.1100
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0649 - val_loss: 0.1133
# Epoch 86/100
#
# Epoch 00086: val_loss did not improve from 0.10973
# 200/200 - 111s - loss: 0.0645 - val_loss: 0.1132
# Epoch 87/100
#
# Epoch 00087: val_loss improved from 0.10973 to 0.10936, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0638 - val_loss: 0.1094
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0637 - val_loss: 0.1108
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0639 - val_loss: 0.1103
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0640 - val_loss: 0.1132
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0635 - val_loss: 0.1125
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0626 - val_loss: 0.1116
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0630 - val_loss: 0.1104
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0631 - val_loss: 0.1116
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0631 - val_loss: 0.1100
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0625 - val_loss: 0.1115
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.10936
# 200/200 - 111s - loss: 0.0617 - val_loss: 0.1109
# Epoch 98/100
#
# Epoch 00098: val_loss improved from 0.10936 to 0.10900, saving model to /content/training/DenseDepth.ckpt
# 200/200 - 112s - loss: 0.0621 - val_loss: 0.1090
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.10900
# 200/200 - 111s - loss: 0.0621 - val_loss: 0.1110
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.10900
# 200/200 - 111s - loss: 0.0616 - val_loss: 0.1100

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(15, 8))

plt.plot(epochs_range, loss, label='Training loss')
plt.plot(epochs_range, val_loss, label='Validation loss')
plt.legend(loc='upper right')
plt.title('Training and Validation loss')
os.chdir(SAVE_PATH)
plt.savefig('loss.png')

# %% [markdown]
# # Test Helper functions

# %% [markdown]
# ## Utils

# %%
import cv2
import numpy as np

def DepthNorm(x, maxDepth):
    return maxDepth / x

def predict(model, images, minDepth=10, maxDepth=1000, batch_size=2):
    # Support multiple RGBs, one RGB image, even grayscale 
    if len(images.shape) < 3: images = np.stack((images,images,images), axis=2)
    if len(images.shape) < 4: images = images.reshape((1, images.shape[0], images.shape[1], images.shape[2]))
    # Compute predictions
    predictions = model.predict(images, batch_size=batch_size)
    # Put in expected range
    return np.clip(DepthNorm(predictions, maxDepth=maxDepth), minDepth, maxDepth) / maxDepth

# %% [markdown]
# # Test

# %%
os.chdir(SAVE_PATH)
print('Loading model...')
model = DenseDepth()
checkpoint_path = "training/DenseDepth.ckpt"
model.load_weights(checkpoint_path)
print('Model weights loaded.')
# Out:
# Loading model...
# Model weights loaded.

# %%
count = 5

os.chdir(SAVE_PATH)
path_pre = DATA_PATH + 'data/nyu2_test/'
files = [f for f in os.listdir(path_pre) if f.split('_')[1] == 'colors.png']
(fig, axes) = plt.subplots(nrows=count, ncols=3, figsize=(15,15))
i = 0
for f in files:
    file_id = f.split('_')[0]
    depth_file = file_id + '_depth.png'
    img = cv2.imread(path_pre + f, cv2.IMREAD_COLOR)
    axes[i][0].imshow(img)
    axes[i][0].set_title('OG')

    img = np.clip(img/255, 0, 1)
    img = predict(model, img, batch_size=1)
    axes[i][2].imshow(img[0,:,:,0], cmap='plasma')
    axes[i][2].set_title('Predicted')

    img = cv2.imread(path_pre + depth_file, cv2.IMREAD_ANYDEPTH)
    axes[i][1].imshow(img, cmap='plasma')
    axes[i][1].set_title('GT')
    
    if i == count-1:
        break
    else:
        i += 1

plt.savefig('result.png')
